# %%
import pandas as pd

# %%
coffee = pd.read_csv('./coffee.csv')

# %%
coffee.head()    # got me top 5 entries of the data
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
# working with csv is the best option to choose because as compared to parquet and xlsx, csv files take lesser time than these all

# %%
results =  pd.read_parquet("results.parquet")

# %%
olympics = pd.read_excel("olympics-data.xlsx")
