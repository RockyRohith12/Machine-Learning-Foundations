# %%
import pandas as pd

# %%
df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]], columns = ["A","B","C"], index = ["a","b","c"])

df.describe()      # very useful mathematical caluclating function
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
df.nunique()  #gets the number of unique elements in the columns
# Out:
# A    3
# B    3
# C    3
# dtype: int64

# %%
df['A'].unique()   #gets unique value of the particular column
# Out:
# array([1, 4, 7])

# %%
df.shape   #shape of the dataframe
# Out:
# (3, 3)

# %%
df.size   #indicates the size of the dataframe
# Out:
# 9
